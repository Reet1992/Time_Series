# %%
### Provincial job posting canada###

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:\Users\Reet\Downloads\dataset\Time_series\provincial_job_canada\provincial_postings_ca.csv')

df['date'] = pd.to_datetime(df['date'])

df['day'] = df['date'].map(lambda x: x.day)
df['month'] = df['date'].map(lambda x: x.month)
df['year'] = df['date'].map(lambda x: x.year)

print(df.head(3))
# Out:
#         date province  indeed_job_postings_index  day  month  year
# 0 2020-02-01       ab                     100.00    1      2  2020
# 1 2020-02-02       ab                      99.86    2      2  2020
# 2 2020-02-03       ab                      99.83    3      2  2020

# %%
df['province'].unique()
# Out:
# array(['ab', 'bc', 'mb', 'nb', 'nl', 'ns', 'nt', 'nu', 'on', 'pe', 'qc',
#        'sk', 'yt'], dtype=object)

# %%
ab = df[df['province'] == 'ab']
ab = ab.drop(['province', 'day','month','year'], axis=1)

bc = df[df['province'] == 'bc']
bc = bc.drop(['province', 'day','month','year'], axis=1)

mb = df[df['province'] == 'mb']
mb = mb.drop(['province', 'day','month','year'], axis=1)

nb = df[df['province'] == 'nb']
nb = nb.drop(['province', 'day','month','year'], axis=1)

nl = df[df['province'] == 'nl']
nl = nl.drop(['province', 'day','month','year'], axis=1)

ns = df[df['province'] == 'ns']
ns = ns.drop(['province', 'day','month','year'], axis=1)

nt = df[df['province'] == 'nt']
nt = nt.drop(['province', 'day','month','year'], axis=1)

nu = df[df['province'] == 'nu']
nu = nu.drop(['province', 'day','month','year'], axis=1)

on = df[df['province'] == 'on']
on = on.drop(['province', 'day','month','year'], axis=1)

pe = df[df['province'] == 'pe']
pe = pe.drop(['province', 'day','month','year'], axis=1)

qc = df[df['province'] == 'qc']
qc = qc.drop(['province', 'day','month','year'], axis=1)

sk = df[df['province'] == 'sk']
sk = sk.drop(['province', 'day','month','year'], axis=1)

yt = df[df['province'] == 'yt']
yt = yt.drop(['province', 'day','month','year'], axis=1)

# %%
ab.head()
# Out:
#         date  indeed_job_postings_index
# 0 2020-02-01                     100.00
# 1 2020-02-02                      99.86
# 2 2020-02-03                      99.83
# 3 2020-02-04                      99.74
# 4 2020-02-05                      99.61

# %%
df['province'].unique()
# Out:
# array(['ab', 'bc', 'mb', 'nb', 'nl', 'ns', 'nt', 'nu', 'on', 'pe', 'qc',
#        'sk', 'yt'], dtype=object)

# %%
ab2= ab.groupby('date')['indeed_job_postings_index'].sum().reset_index()
ab2['date'] = pd.to_datetime(ab['date'])
ab2= ab2.set_index('date')
ab2['indeed_job_postings_index'] = np.log(ab2['indeed_job_postings_index'])
print(ab2.index)
print(ab2.skew().sort_values(ascending=False))

bc= bc.groupby('date')['indeed_job_postings_index'].sum().reset_index()
bc['date'] = pd.to_datetime(bc['date'])
bc= bc.set_index('date')
bc['indeed_job_postings_index'] = np.log(bc['indeed_job_postings_index'])
print(bc.index)
print(bc.skew().sort_values(ascending=False)) 

mb= mb.groupby('date')['indeed_job_postings_index'].sum().reset_index()
mb['date'] = pd.to_datetime(mb['date'])
mb= mb.set_index('date')
mb['indeed_job_postings_index'] = np.log(mb['indeed_job_postings_index'])
print(mb.index)
print(mb.skew().sort_values(ascending=False)) 

nb= nb.groupby('date')['indeed_job_postings_index'].sum().reset_index()
nb['date'] = pd.to_datetime(nb['date'])
nb= nb.set_index('date')
nb['indeed_job_postings_index'] = np.log(nb['indeed_job_postings_index'])
print(nb.index)
print(nb.skew().sort_values(ascending=False)) 

nl= nl.groupby('date')['indeed_job_postings_index'].sum().reset_index()
nl['date'] = pd.to_datetime(nl['date'])
nl= nl.set_index('date')
nl['indeed_job_postings_index'] = np.log(nl['indeed_job_postings_index'])
print(nl.index)
print(nl.skew().sort_values(ascending=False)) 

ns= ns.groupby('date')['indeed_job_postings_index'].sum().reset_index()
ns['date'] = pd.to_datetime(ns['date'])
ns= ns.set_index('date')
ns['indeed_job_postings_index'] = np.log(ns['indeed_job_postings_index'])
print(ns.index)
print(ns.skew().sort_values(ascending=False)) 

nt= nt.groupby('date')['indeed_job_postings_index'].sum().reset_index()
nt['date'] = pd.to_datetime(nt['date'])
nt= nt.set_index('date')
nt['indeed_job_postings_index'] = np.log(nt['indeed_job_postings_index'])
print(nt.index)
print(nt.skew().sort_values(ascending=False)) 

nu= nu.groupby('date')['indeed_job_postings_index'].sum().reset_index()
nu['date'] = pd.to_datetime(nu['date'])
nu= nu.set_index('date')
nu['indeed_job_postings_index'] = np.log(nu['indeed_job_postings_index'])
print(nu.index)
print(nu.skew().sort_values(ascending=False)) 

on= on.groupby('date')['indeed_job_postings_index'].sum().reset_index()
on['date'] = pd.to_datetime(on['date'])
on= on.set_index('date')
on['indeed_job_postings_index'] = np.log(on['indeed_job_postings_index'])
print(on.index)
print(on.skew().sort_values(ascending=False)) 

pe= pe.groupby('date')['indeed_job_postings_index'].sum().reset_index()
pe['date'] = pd.to_datetime(pe['date'])
pe= pe.set_index('date')
pe['indeed_job_postings_index'] = np.log(pe['indeed_job_postings_index'])
print(pe.index)
print(pe.skew().sort_values(ascending=False)) 

qc= qc.groupby('date')['indeed_job_postings_index'].sum().reset_index()
qc['date'] = pd.to_datetime(qc['date'])
qc= qc.set_index('date')
qc['indeed_job_postings_index'] = np.log(qc['indeed_job_postings_index'])
print(qc.index)
print(qc.skew().sort_values(ascending=False)) 

sk= sk.groupby('date')['indeed_job_postings_index'].sum().reset_index()
sk['date'] = pd.to_datetime(sk['date'])
sk= sk.set_index('date')
sk['indeed_job_postings_index'] = np.log(sk['indeed_job_postings_index'])
print(sk.index)
print(sk.skew().sort_values(ascending=False)) 

yt= yt.groupby('date')['indeed_job_postings_index'].sum().reset_index()
yt['date'] = pd.to_datetime(yt['date'])
yt= yt.set_index('date')
yt['indeed_job_postings_index'] = np.log(yt['indeed_job_postings_index'])
print(yt.index)
print(yt.skew().sort_values(ascending=False))
# Out:
# DatetimeIndex(['2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04',
#                '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08',
#                '2020-02-09', '2020-02-10',
#                ...
#                '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-29',
#                '2023-07-30', '2023-07-31', '2023-08-01', '2023-08-02',
#                '2023-08-03', '2023-08-04'],
#               dtype='datetime64[ns]', name='date', length=1281, freq=None)
# indeed_job_postings_index   -0.872437
# dtype: float64
# DatetimeIndex(['2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04',
#                '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08',
#                '2020-02-09', '2020-02-10',
#                ...
#                '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-29',
#                '2023-07-30', '2023-07-31', '2023-08-01', '2023-08-02',
#                '2023-08-03', '2023-08-04'],
# ...

# %%
ab.head(3)
# Out:
#             indeed_job_postings_index
# date
# 2020-02-01                   4.605170
# 2020-02-02                   4.603769
# 2020-02-03                   4.603469

# %%
#### Original Plot
ab.plot(figsize=(20, 8))
bc.plot(figsize=(20, 8))
plt.show()

# %%
ab.head()
# Out:
#             indeed_job_postings_index
# date
# 2020-02-01                   4.605170
# 2020-02-02                   4.603769
# 2020-02-03                   4.603469
# 2020-02-04                   4.602567
# 2020-02-05                   4.601263

# %%
df['province'].unique()
# Out:
# array(['ab', 'bc', 'mb', 'nb', 'nl', 'ns', 'nt', 'nu', 'on', 'pe', 'qc',
#        'sk', 'yt'], dtype=object)

# %%
ab.rename(columns = {'indeed_job_postings_index':'ab'}, inplace = True)
bc.rename(columns = {'indeed_job_postings_index':'bc'}, inplace = True)
mb.rename(columns = {'indeed_job_postings_index':'mb'}, inplace = True)
nb.rename(columns = {'indeed_job_postings_index':'nb'}, inplace = True)
nl.rename(columns = {'indeed_job_postings_index':'nl'}, inplace = True)
ns.rename(columns = {'indeed_job_postings_index':'ns'}, inplace = True)
nt.rename(columns = {'indeed_job_postings_index':'nt'}, inplace = True)
nu.rename(columns = {'indeed_job_postings_index':'nu'}, inplace = True)
on.rename(columns = {'indeed_job_postings_index':'on'}, inplace = True)
pe.rename(columns = {'indeed_job_postings_index':'pe'}, inplace = True)
qc.rename(columns = {'indeed_job_postings_index':'qc'}, inplace = True)
sk.rename(columns = {'indeed_job_postings_index':'sk'}, inplace = True)
yt.rename(columns = {'indeed_job_postings_index':'yt'}, inplace = True)

# %%
#ab['bc'] = bc['bc']
#ab['mb'] = mb['mb']
#ab['nb'] = nb['nb']
#ab['nl'] = nl['nl']
#ab['ns'] = ns['ns']
#ab['nt'] = nt['nt']
#ab['nu'] = nu['nu']
#ab['on'] = on['on']
#ab['pe'] = pe['pe']
#ab['qc'] = qc['qc']
#ab['sk'] = sk['sk']
#ab['yt'] = yt['yt']

# %%
ab
# Out:
#                   ab        bc        mb        nb        nl        ns  \
# date
# 2020-02-01  4.605170  4.605170  4.605170  4.605170  4.605170  4.605170
# 2020-02-02  4.603769  4.605970  4.602667  4.603369  4.608066  4.605770
# 2020-02-03  4.603469  4.606969  4.602065  4.603369  4.611947  4.607567
# 2020-02-04  4.602567  4.608066  4.605070  4.604370  4.616802  4.609361
# 2020-02-05  4.601263  4.608564  4.607966  4.608265  4.621240  4.612543
# ...              ...       ...       ...       ...       ...       ...
# 2023-07-31  5.049600  4.776094  4.902753  4.924351  5.015755  5.039741
# 2023-08-01  5.047931  4.773139  4.900672  4.921877  5.012700  5.042134
# 2023-08-02  5.044521  4.767544  4.899778  4.920346  5.009768  5.042134
# 2023-08-03  5.041035  4.761148  4.900076  4.916251  5.002200  5.041876
# 2023-08-04  5.039158  4.757548  4.903124  4.915298  4.997212  5.044457
#
#                   nt        nu        on        pe        qc        sk  \
# date
# ...

# %%
pr_df
# Out:
#                   ab        bc        mb        nb        nl        ns  \
# date
# 2020-02-01  4.605170  4.605170  4.605170  4.605170  4.605170  4.605170
# 2020-02-02  4.603769  4.605970  4.602667  4.603369  4.608066  4.605770
# 2020-02-03  4.603469  4.606969  4.602065  4.603369  4.611947  4.607567
# 2020-02-04  4.602567  4.608066  4.605070  4.604370  4.616802  4.609361
# 2020-02-05  4.601263  4.608564  4.607966  4.608265  4.621240  4.612543
# ...              ...       ...       ...       ...       ...       ...
# 2023-07-31  5.049600  4.776094  4.902753  4.924351  5.015755  5.039741
# 2023-08-01  5.047931  4.773139  4.900672  4.921877  5.012700  5.042134
# 2023-08-02  5.044521  4.767544  4.899778  4.920346  5.009768  5.042134
# 2023-08-03  5.041035  4.761148  4.900076  4.916251  5.002200  5.041876
# 2023-08-04  5.039158  4.757548  4.903124  4.915298  4.997212  5.044457
#
#                   nt        nu        on        pe        qc        sk  \
# date
# ...

# %%
ax = pr_df.plot(figsize=(25,12),linewidth=2,grid=True, alpha=1)
#xtick = pd.date_range( start=ax.index.min( ), end=ts.index.max( ), freq='W' )
#ax.set_xticks( xtick, minor=True )
ax.grid('on', which='minor', axis='x' )
#ax.grid('off', which='major', axis='x' )

# %%
pr_df['ab']
# Out:
# date
# 2020-02-01    4.605170
# 2020-02-02    4.603769
# 2020-02-03    4.603469
# 2020-02-04    4.602567
# 2020-02-05    4.601263
#                 ...
# 2023-07-31    5.049600
# 2023-08-01    5.047931
# 2023-08-02    5.044521
# 2023-08-03    5.041035
# 2023-08-04    5.039158
# Name: ab, Length: 1281, dtype: float64

# %%
df['province'].unique()
# Out:
# array(['ab', 'bc', 'mb', 'nb', 'nl', 'ns', 'nt', 'nu', 'on', 'pe', 'qc',
#        'sk', 'yt'], dtype=object)

# %%
from statsmodels.tsa import seasonal

##AB##

d_ab = seasonal.seasonal_decompose(x=pr_df['ab'], freq=22, extrapolate_trend='freq',model = 'additive')
fig = d_ab.plot()
plt.show()

import warnings
import itertools
warnings.filterwarnings("ignore")
import statsmodels.api as sm

from pylab import rcParams
rcParams['figure.figsize'] = 18, 8 

p = d = q = range(0, 2)
pd = list(itertools.product(p, d, q))  
seasonal_pd = [(x[0], x[1], x[2],16) for x in list(itertools.product(p, d,q))] 

print(seasonal_pd)

for param in pd:
    for param_seasonal in seasonal_pd:        
        mod_ab = sm.tsa.statespace.SARIMAX(pr_df['ab'])
        mod_bc = sm.tsa.statespace.SARIMAX(pr_df['bc']) 
        mod_mb = sm.tsa.statespace.SARIMAX(pr_df['mb'])
        mod_nb = sm.tsa.statespace.SARIMAX(pr_df['nb'])
        mod_nl = sm.tsa.statespace.SARIMAX(pr_df['nl'])
        mod_ns = sm.tsa.statespace.SARIMAX(pr_df['ns'])
        mod_nt = sm.tsa.statespace.SARIMAX(pr_df['nt'])
        mod_nu = sm.tsa.statespace.SARIMAX(pr_df['nu'])
        mod_on = sm.tsa.statespace.SARIMAX(pr_df['on'])
        mod_pe = sm.tsa.statespace.SARIMAX(pr_df['pe'])
        mod_qc = sm.tsa.statespace.SARIMAX(pr_df['qc'])
        mod_sk = sm.tsa.statespace.SARIMAX(pr_df['sk'])
        mod_yt = sm.tsa.statespace.SARIMAX(pr_df['yt'])
        
results_ab = mod_ab.fit()
results_bc = mod_bc.fit()
results_mb = mod_mb.fit()
results_nb = mod_nb.fit()
results_nl = mod_nl.fit()
results_ns = mod_ns.fit()
results_nt = mod_nt.fit()
results_nu = mod_nu.fit()
results_on = mod_on.fit()
results_pe = mod_pe.fit()
results_qc = mod_qc.fit()
results_sk = mod_sk.fit()
results_yt = mod_yt.fit() 

print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_ab.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_bc.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_mb.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_nb.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_nl.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_ns.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_nt.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_nu.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_on.aic)) 
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_qc.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_sk.aic))
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_yt.aic))

### Fitting with the latest Value

mod_ab = sm.tsa.statespace.SARIMAX(pr_df['ab'])
results_ab = mod_ab.fit()
mod_bc = sm.tsa.statespace.SARIMAX(pr_df['bc']) 
results_bc = mod_bc.fit()
mod_mb = sm.tsa.statespace.SARIMAX(pr_df['mb'])
results_mb = mod_mb.fit()
mod_nb = sm.tsa.statespace.SARIMAX(pr_df['nb'])
results_nb = mod_nb.fit()
mod_nl = sm.tsa.statespace.SARIMAX(pr_df['nl'])
results_nl = mod_nl.fit()
mod_ns = sm.tsa.statespace.SARIMAX(pr_df['ns'])
results_ns = mod_ns.fit()
mod_nt = sm.tsa.statespace.SARIMAX(pr_df['nt'])
results_nt = mod_nt.fit()
mod_nu = sm.tsa.statespace.SARIMAX(pr_df['nu'])
results_nu = mod_nu.fit()
mod_on = sm.tsa.statespace.SARIMAX(pr_df['on'])
results_on = mod_on.fit()
mod_pe = sm.tsa.statespace.SARIMAX(pr_df['pe'])
results_pe = mod_pe.fit()
mod_qc = sm.tsa.statespace.SARIMAX(pr_df['qc'])
results_qc = mod_qc.fit()
mod_sk = sm.tsa.statespace.SARIMAX(pr_df['sk'])
results_sk = mod_sk.fit()
mod_yt = sm.tsa.statespace.SARIMAX(pr_df['yt'])
results_yt = mod_yt.fit()

print(results_ab.summary())
print(results_bc.summary())
print(results_mb.summary())
print(results_nb.summary())
print(results_nl.summary())
print(results_ns.summary())
print(results_nt.summary())
print(results_nu.summary())
print(results_on.summary())
print(results_pe.summary())
print(results_qc.summary())
print(results_sk.summary()) 
print(results_yt.summary()) 


#### plot_result_diagnostic statistics ##

results_ab.plot_diagnostics(figsize=(16, 8))
plt.show()

results_bc.plot_diagnostics(figsize=(16, 8))
plt.show()

results_mb.plot_diagnostics(figsize=(16, 8))
plt.show()

results_nb.plot_diagnostics(figsize=(16, 8))
plt.show()

results_nl.plot_diagnostics(figsize=(16, 8))
plt.show() 

results_ns.plot_diagnostics(figsize=(16, 8))
plt.show() 

results_nt.plot_diagnostics(figsize=(16, 8))
plt.show()

results_nu.plot_diagnostics(figsize=(16, 8))
plt.show()

results_on.plot_diagnostics(figsize=(16, 8))
plt.show() 

results_pe.plot_diagnostics(figsize=(16, 8))
plt.show()

results_qc.plot_diagnostics(figsize=(16, 8))
plt.show()

results_sk.plot_diagnostics(figsize=(16, 8))
plt.show()

results_yt.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# [(0, 0, 0, 16), (0, 0, 1, 16), (0, 1, 0, 16), (0, 1, 1, 16), (1, 0, 0, 16), (1, 0, 1, 16), (1, 1, 0, 16), (1, 1, 1, 16)]
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-9794.652177430386
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-10316.44589381459
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-10155.119160379529
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-9912.872669828841
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-8858.93879905457
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-9665.524709858788
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-8229.490318045719
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-7489.265348875046
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-10127.170328927983
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-10261.623101789115
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-9884.702144737328
# ARIMA(1, 1, 1)x(1, 1, 1, 16)12 - AIC:-8379.506408812009
#                                SARIMAX Results
# ...
# Dep. Variable:                     ab   No. Observations:                 1281
# ...

# %%
### predicted values for future ##

pred_ab = results.get_prediction(start='2023-05-17', end='2024-02-14', dynamic=False)
pred_ab2 = pred_ab.conf_int()

# %%
pred_ab2.head(3)
# Out:
#             lower ab  upper ab
# 2023-05-17  5.125313  5.145925
# 2023-05-18  5.122956  5.143569
# 2023-05-19  5.120181  5.140793

# %%
ab.head(5)
# Out:
#         date  indeed_job_postings_index
# 0 2020-02-01                     100.00
# 1 2020-02-02                      99.86
# 2 2020-02-03                      99.83
# 3 2020-02-04                      99.74
# 4 2020-02-05                      99.61

# %%
ab_final = ab.reset_index().set_index('date')

# %%
ab_final = ab_final.drop(['index'], axis=1)

# %%
ab_final
# Out:
#             indeed_job_postings_index
# date
# 2020-02-01                     100.00
# 2020-02-02                      99.86
# 2020-02-03                      99.83
# 2020-02-04                      99.74
# 2020-02-05                      99.61
# ...                               ...
# 2023-07-31                     155.96
# 2023-08-01                     155.70
# 2023-08-02                     155.17
# 2023-08-03                     154.63
# 2023-08-04                     154.34
#
# [1281 rows x 1 columns]

# %%
pred_ab2
# Out:
#             lower ab  upper ab
# 2023-05-17  5.125313  5.145925
# 2023-05-18  5.122956  5.143569
# 2023-05-19  5.120181  5.140793
# 2023-05-20  5.121245  5.141857
# 2023-05-21  5.119530  5.140143
# ...              ...       ...
# 2024-02-10  4.896533  5.180642
# 2024-02-11  4.896157  5.181012
# 2024-02-12  4.895782  5.181382
# 2024-02-13  4.895407  5.181750
# 2024-02-14  4.895034  5.182117
#
# [274 rows x 2 columns]

# %%
#alberta One step ahead forecast

pred_ab = results_ab.get_prediction(start='2023-05-17', end='2024-02-14', dynamic=False)
pred_ab2 = pred_ab.conf_int()

ax = pred_ab2['2020-04-21':].plot(label='observed')
pred_ab.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(10, 5))


ax.fill_between(pred_ab2.index,pred_ab2.iloc[:, 0],pred_ab2.iloc[:, 1], color='k', alpha=.3)


##bc

pred_bc = results_bc.get_prediction(start='2023-05-17', end='2024-02-14', dynamic=False)
pred_bc2 = pred_bc.conf_int()

ax2 = pred_bc2['2020-04-21':].plot(label='observed')
pred_bc.predicted_mean.plot(ax=ax2, label='One-step ahead Forecast', alpha=.7, figsize=(10, 5))

ax2.fill_between(pred_bc2.index,pred_bc2.iloc[:, 0],pred_bc2.iloc[:, 1], color='k', alpha=.3)


ax.set_xlabel('Date')
ax.set_ylabel('Indeed Job Appliation Index')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
arma_rmse_ab = np.sqrt(mean_squared_error(pred_ab2.iloc[:, 0],pred_ab2.iloc[:, 1]))
mae_ab = mean_absolute_error(pred_ab2.iloc[:, 0],pred_ab2.iloc[:, 1])
print('MAE: %f' % mae_ab)
print("RMSE: ",arma_rmse_ab)
# Out:
# MAE: 0.142039
# RMSE:  0.1716169191720409
